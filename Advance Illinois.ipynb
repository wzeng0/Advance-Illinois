# %%
import pandas as pd

# %%
df = pd.read_csv("../Techteam/Data/FY-23-LegSheets - Better Maps Update (1).xlsx - Senate.csv")

# %%
schools = pd.read_csv("../Techteam/Data/FY-23-LegSheets - Better Maps Update (1).xlsx - Senate.csv")
schools = schools[["Type", "SCHOOL DISTRICT", "ENROLLMENT", "% OF FULL \nFUNDING", "TOTAL GAP TO FULL FUNDING", "PER PUPIL GAP TO FULL FUNDING"]]
schools
# Out:
#       Type               SCHOOL DISTRICT  ENROLLMENT % OF FULL \nFUNDING  \
# 0       16  WASHINGTON COMM H S DIST 308      1469.0                 59%
# 1       16  WASHINGTON COMM H S DIST 308      1469.0                 59%
# 2        2  CHANEY-MONGE SCH DISTRICT 88       476.0                 59%
# 3        2  CHANEY-MONGE SCH DISTRICT 88       476.0                 59%
# 4        2  CENTRAL CITY SCHOOL DIST 133       347.0                 60%
# ...    ...                           ...         ...                 ...
# 1491     2  ROSEMONT ELEM SCHOOL DIST 78       195.0                249%
# 1492     2        RONDOUT SCHOOL DIST 72       144.0                269%
# 1493     2        RONDOUT SCHOOL DIST 72       144.0                269%
# 1494    16   OHIO COMMUNITY H S DIST 505        32.0                270%
# 1495    30                           NaN         NaN                 NaN
#
#      TOTAL GAP TO FULL FUNDING PER PUPIL GAP TO FULL FUNDING
# ...

# %%
legislators = pd.read_csv("../Techteam/Data/103rd GA Legislators.xlsx - 103rd Senate.csv")
legislators = legislators[["Senator", "District"]]
legislators
# Out:
#                       Senator  District
# 0          Javier L Cervantes         1
# 1                 Omar Aquino         2
# 2               Mattie Hunter         3
# 3       Kimberly A. Lightford         4
# 4           Patricia Van Pelt         5
# 5            Sara Feigenholtz         6
# 6                Mike Simmons         7
# 7              Ram Villivalam         8
# 8                  Laura Fine         9
# 9          Robert F. Martwick        10
# 10              Mike Porfirio        11
# 11          Celina Villanueva        12
# 12              Robert Peters        13
# 13            Emil Jones, III        14
# 14       Napoleon Harris, III        15
# 15             Willie Preston        16
# 16         Elgie R. Sims, Jr.        17
# 17            Bill Cunningham        18
# 18        Michael E. Hastings        19
# 19  Cristina H. Pacione-Zayas        20
# 20               Laura Ellman        21
# 21            Cristina Castro        22
# ...
